# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fishsense_api_workflow_worker.database import Database
from fishsense_api_workflow_worker.models.dive import Dive
from datetime import datetime

# %%
database = Database()

# %%
await database.insert_dive(Dive(path = "/my_path", dive_datetime=datetime.now()))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolationError                      Traceback (most recent call last)
# File /app/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/asyncpg.py:545, in AsyncAdapt_asyncpg_cursor._prepare_and_execute(self, operation, parameters)
#     544 else:
# --> 545     self._rows = deque(await prepared_stmt.fetch(*parameters))
#     546     status = prepared_stmt.get_statusmsg()
#
# File /app/.venv/lib/python3.13/site-packages/asyncpg/prepared_stmt.py:176, in PreparedStatement.fetch(self, timeout, *args)
#     168 r"""Execute the statement and return a list of :class:`Record` objects.
#     169
#     170 :param str query: Query text
#    (...)    174 :return: A list of :class:`Record` instances.
#     175 """
# --> 176 data = await self.__bind_execute(args, 0, timeout)
#     177 return data
#
# ...

# %%
dive = await database.select_dive_by_path("/my_path")

dive
# Out:
# Dive(path='/my_path', dive_datetime=datetime.datetime(2025, 9, 1, 3, 15, 17, 444324), id=3)
