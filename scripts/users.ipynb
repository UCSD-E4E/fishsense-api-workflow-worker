# %%
from label_studio_sdk.client import LabelStudio
from fishsense_api_workflow_worker.config import settings

# %%
client = LabelStudio(base_url=f"https://{settings.label_studio.host}", api_key=settings.label_studio.api_key)

# %%
users = client.users.list()

users
# Out:
# [LseUserApi(id=23, first_name='', last_name='', username='francisrumsky', email='francisrumsky@gmail.com', last_activity=datetime.datetime(2025, 8, 29, 10, 39, 39, 30479, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='fr', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=3, first_name='', last_name='', username='toyang', email='toyang@ucsd.edu', last_activity=datetime.datetime(2025, 1, 27, 18, 55, 56, 411817, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='to', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=12, first_name='', last_name='', username='vpabba', email='vpabba@ucsd.edu', last_activity=datetime.datetime(2025, 2, 24, 20, 58, 53, 872729, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='vp', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=32, first_name='', last_name='', username='brusart', email='brusart@gmail.com', last_activity=datetime.datetime(2025, 6, 4, 14, 28, 28, 142720, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='br', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=7, first_name='', last_name='', username='eschleef', email='eschleef@ucsd.edu', last_activity=datetime.datetime(2025, 6, 17, 18, 24, 9, 156608, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='es', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=13, first_name='', last_name='', username='alkan', email='alkan@ucsd.edu', last_activity=datetime.datetime(2024, 11, 21, 23, 29, 12, 281696, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='al', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=14, first_name='', last_name='', username='diana.phillips', email='diana.phillips@reef.org', last_activity=datetime.datetime(2024, 11, 21, 18, 57, 43, 429459, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='di', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=17, first_name='', last_name='', username='ntlhui', email='ntlhui@gmail.com', last_activity=datetime.datetime(2024, 11, 22, 22, 17, 34, 775438, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='nt', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=24, first_name='', last_name='', username='tflar', email='tflar@ucsd.edu', last_activity=datetime.datetime(2025, 2, 10, 2, 33, 1, 206433, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='tf', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=8, first_name='', last_name='', username='shperry', email='shperry@ucsd.edu', last_activity=datetime.datetime(2025, 8, 29, 16, 50, 36, 876515, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sh', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=2, first_name='', last_name='', username='nthui', email='nthui@ucsd.edu', last_activity=datetime.datetime(2025, 5, 24, 3, 42, 21, 77547, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='nt', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=9, first_name='', last_name='', username='bbmcca26', email='bbmcca26@g.holycross.edu', last_activity=datetime.datetime(2025, 1, 29, 18, 18, 8, 155657, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='bb', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=5, first_name='', last_name='', username='kastner', email='kastner@ucsd.edu', last_activity=datetime.datetime(2025, 5, 12, 20, 0, 57, 981052, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ka', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=19, first_name='Natalee', last_name='Webster', username='natwebste', email='natwebste@gmail.com', last_activity=datetime.datetime(2024, 12, 12, 19, 48, 21, 946480, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='NW', phone='5038670492', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=6, first_name='', last_name='', username='a8ghosh', email='a8ghosh@ucsd.edu', last_activity=datetime.datetime(2025, 5, 9, 19, 30, 59, 824491, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='a8', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=30, first_name='', last_name='', username='davidr.808', email='davidr.808@gmail.com', last_activity=datetime.datetime(2025, 4, 17, 6, 42, 46, 22346, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='da', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=72, first_name='', last_name='', username='kellieisaacks', email='kellieisaacks@gmail.com', last_activity=datetime.datetime(2025, 1, 23, 2, 3, 45, 978996, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ke', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=25, first_name='', last_name='', username='eci3', email='eci3@reef.org', last_activity=datetime.datetime(2025, 4, 8, 18, 30, 47, 308182, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ec', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=26, first_name='', last_name='', username='jen.loch', email='jen.loch@reef.org', last_activity=datetime.datetime(2025, 8, 28, 23, 28, 40, 238571, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='je', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=38, first_name='', last_name='', username='hmsauder06', email='hmsauder06@gmail.com', last_activity=datetime.datetime(2024, 12, 31, 22, 43, 51, 904924, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='hm', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=15, first_name='', last_name='', username='sprestrelski', email='sprestrelski@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 2, 36, 22, 936503, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sp', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=40, first_name='', last_name='', username='rebeccamalley', email='rebeccamalley@gmail.com', last_activity=datetime.datetime(2025, 1, 10, 0, 32, 2, 629319, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='re', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=28, first_name='', last_name='', username='apotter', email='apotter@students.pitzer.edu', last_activity=datetime.datetime(2024, 12, 10, 21, 32, 32, 565869, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ap', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=128, first_name='', last_name='', username='taylorvh2000', email='taylorvh2000@gmail.com', last_activity=datetime.datetime(2025, 5, 15, 2, 45, 56, 973583, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ta', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=10, first_name='', last_name='', username='alli', email='alli@reef.org', last_activity=datetime.datetime(2025, 7, 28, 18, 0, 43, 807811, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='al', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=130, first_name='', last_name='', username='aeswaran', email='aeswaran@ucsd.edu', last_activity=datetime.datetime(2025, 6, 12, 0, 13, 31, 829624, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ae', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=31, first_name='', last_name='', username='debby.ruoss', email='debby.ruoss@gmail.com', last_activity=datetime.datetime(2024, 12, 15, 11, 1, 42, 246613, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='de', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=94, first_name='', last_name='', username='daris.chen', email='daris.chen@gmail.com', last_activity=datetime.datetime(2025, 2, 27, 6, 30, 47, 494818, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='da', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=20, first_name='John', last_name='Bychok', username='jbychok', email='jbychok@gmail.com', last_activity=datetime.datetime(2025, 8, 11, 20, 38, 7, 997170, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='JB', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=16, first_name='', last_name='', username='dave.engineer', email='dave.engineer@gmail.com', last_activity=datetime.datetime(2025, 3, 30, 17, 58, 58, 386618, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='da', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=73, first_name='', last_name='', username='john.r.teasley', email='john.r.teasley@gmail.com', last_activity=datetime.datetime(2025, 2, 23, 15, 40, 17, 382357, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='jo', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=37, first_name='', last_name='', username='tantillomarine', email='tantillomarine@gmail.com', last_activity=datetime.datetime(2025, 4, 5, 15, 35, 37, 491726, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ta', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=36, first_name='', last_name='', username='kdgarsh', email='kdgarsh@hotmail.com', last_activity=datetime.datetime(2025, 2, 5, 22, 33, 51, 616884, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='kd', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=11, first_name='Coryn', last_name='Ferguson', username='fergusoncoryn5', email='fergusoncoryn5@gmail.com', last_activity=datetime.datetime(2024, 12, 12, 21, 56, 52, 713111, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='CF', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=41, first_name='', last_name='', username='rebecca.malley', email='rebecca.malley@gmail.com', last_activity=datetime.datetime(2024, 12, 20, 17, 2, 25, 414743, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='re', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=79, first_name='', last_name='', username='e3becker', email='e3becker@ucsd.edu', last_activity=datetime.datetime(2025, 2, 20, 0, 24, 38, 955997, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='e3', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=34, first_name='Karen', last_name='Peck', username='karenpeck5000', email='karenpeck5000@gmail.com', last_activity=datetime.datetime(2025, 9, 1, 19, 6, 48, 730538, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='KP', phone='8455276463', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=77, first_name='', last_name='', username='wew059', email='wew059@ucsd.edu', last_activity=datetime.datetime(2025, 2, 7, 22, 55, 17, 381592, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='we', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=78, first_name='', last_name='', username='sachikoschott', email='sachikoschott@live.ca', last_activity=datetime.datetime(2025, 3, 25, 22, 51, 21, 938063, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sa', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=54, first_name='Felicia', last_name='Thompson', username='fjrthompson', email='fjrthompson@gmail.com', last_activity=datetime.datetime(2025, 3, 26, 20, 3, 29, 539474, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='FT', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=47, first_name='', last_name='', username='divemastermark', email='divemastermark@bellsouth.net', last_activity=datetime.datetime(2025, 8, 27, 14, 34, 39, 100978, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='di', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=50, first_name='', last_name='', username='divedive168', email='divedive168@gmail.com', last_activity=datetime.datetime(2025, 5, 19, 9, 33, 42, 827631, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='di', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=39, first_name='', last_name='', username='ridley.chizick', email='ridley.chizick@gmail.com', last_activity=datetime.datetime(2024, 12, 21, 20, 37, 24, 580028, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ri', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=57, first_name='terence', last_name='zahner', username='tzahner', email='tzahner@gmail.com', last_activity=datetime.datetime(2025, 7, 1, 23, 10, 40, 677698, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='tz', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=80, first_name='', last_name='', username='k1ross', email='k1ross@ucsd.edu', last_activity=datetime.datetime(2025, 7, 23, 0, 17, 8, 859620, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='k1', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=52, first_name='', last_name='', username='saigudlavalleti', email='saigudlavalleti@gmail.com', last_activity=datetime.datetime(2025, 1, 15, 22, 36, 31, 646247, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sa', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=91, first_name='', last_name='', username='alrowley', email='alrowley@ucsd.edu', last_activity=datetime.datetime(2025, 2, 26, 20, 8, 13, 201824, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='al', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=1, first_name='', last_name='', username='', email='e4e@ucsd.edu', last_activity=datetime.datetime(2024, 11, 23, 2, 38, 19, 683140, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='e4', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=None, date_joined=None, org_membership=None),
#  LseUserApi(id=42, first_name='', last_name='', username='ann_firestine', email='ann_firestine@yahoo.com', last_activity=datetime.datetime(2024, 12, 30, 23, 35, 21, 597815, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='an', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=81, first_name='', last_name='', username='waterhlz', email='waterhlz@gmail.com', last_activity=datetime.datetime(2025, 4, 9, 16, 4, 36, 118311, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='wa', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=76, first_name='', last_name='', username='eci2', email='eci2@reef.org', last_activity=datetime.datetime(2025, 4, 2, 23, 53, 43, 970692, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ec', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=46, first_name='', last_name='', username='jessarmacsot', email='jessarmacsot@gmail.com', last_activity=datetime.datetime(2025, 9, 1, 16, 0, 43, 51897, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='je', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=129, first_name='', last_name='', username='alyssasanchez22', email='alyssasanchez22@gmail.com', last_activity=datetime.datetime(2025, 5, 13, 4, 11, 52, 262094, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='al', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=45, first_name='', last_name='', username='jessarmacost', email='jessarmacost@gmail.com', last_activity=datetime.datetime(2025, 8, 16, 15, 43, 9, 193639, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='je', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=71, first_name='', last_name='', username='anallacheruvu', email='anallacheruvu@ucsd.edu', last_activity=datetime.datetime(2025, 6, 16, 12, 5, 1, 308977, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='an', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=161, first_name='', last_name='', username='cbeeding22', email='cbeeding22@gmail.com', last_activity=datetime.datetime(2025, 8, 20, 13, 40, 51, 979717, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='cb', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=44, first_name='', last_name='', username='rhartmanz', email='rhartmanz@hotmail.com', last_activity=datetime.datetime(2025, 6, 10, 18, 46, 50, 298866, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='rh', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=51, first_name='', last_name='', username='jonathan.chizick', email='jonathan.chizick@gmail.com', last_activity=datetime.datetime(2025, 4, 16, 1, 54, 12, 767318, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='jo', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=49, first_name='', last_name='', username='erinkeeley55', email='erinkeeley55@gmail.com', last_activity=datetime.datetime(2025, 8, 27, 23, 46, 52, 868287, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='er', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=53, first_name='Aaron', last_name='Enyetu', username='aaronenyetu', email='aaronenyetu@gmail.com', last_activity=datetime.datetime(2025, 8, 17, 15, 3, 10, 135857, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='AE', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=74, first_name='', last_name='', username='cattazelee', email='cattazelee@gmail.com', last_activity=datetime.datetime(2025, 2, 2, 14, 6, 58, 945490, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ca', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=48, first_name='', last_name='', username='karalynfitzgerald', email='karalynfitzgerald@gmail.com', last_activity=datetime.datetime(2025, 1, 28, 16, 39, 1, 166399, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ka', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=56, first_name='', last_name='', username='manuelcoffill', email='manuelcoffill@gmail.com', last_activity=datetime.datetime(2025, 1, 15, 17, 53, 13, 34884, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ma', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=59, first_name='', last_name='', username='renouromane9', email='renouromane9@gmail.com', last_activity=datetime.datetime(2025, 2, 13, 11, 56, 26, 806801, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='re', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=82, first_name='', last_name='', username='talwar.brendan', email='talwar.brendan@gmail.com', last_activity=datetime.datetime(2025, 2, 17, 2, 55, 33, 254083, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ta', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=58, first_name='', last_name='', username='matt', email='matt@mattgilbert.co', last_activity=datetime.datetime(2025, 1, 16, 23, 58, 43, 654559, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ma', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=83, first_name='', last_name='', username='laytonja', email='laytonja@oregonstate.edu', last_activity=datetime.datetime(2025, 2, 17, 13, 10, 53, 908555, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='la', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=85, first_name='', last_name='', username='thouy', email='thouy@ucsd.edu', last_activity=datetime.datetime(2025, 2, 24, 17, 10, 29, 79209, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='th', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=95, first_name='', last_name='', username='ybhatia', email='ybhatia@ucsd.edu', last_activity=datetime.datetime(2025, 3, 3, 21, 7, 8, 73968, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='yb', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=127, first_name='', last_name='', username='aruiz26', email='aruiz26@students.claremontmckenna.edu', last_activity=datetime.datetime(2025, 5, 3, 4, 30, 14, 542645, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ar', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=100, first_name='', last_name='', username='kyt001', email='kyt001@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 1, 4, 6, 1579, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ky', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=137, first_name='', last_name='', username='audreyiloh', email='audreyiloh@gmail.com', last_activity=datetime.datetime(2025, 6, 21, 7, 16, 51, 820712, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='au', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=119, first_name='', last_name='', username='nijian', email='nijian@ucsd.edu', last_activity=datetime.datetime(2025, 5, 14, 19, 2, 59, 913158, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ni', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=55, first_name='Gosia', last_name='Szałęga', username='gosia.szalega', email='gosia.szalega@gmail.com', last_activity=datetime.datetime(2025, 8, 25, 13, 22, 8, 375114, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='GS', phone='+48608274025', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=88, first_name='', last_name='', username='anl139', email='anl139@ucsd.edu', last_activity=datetime.datetime(2025, 3, 3, 20, 54, 43, 128021, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='an', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=99, first_name='', last_name='', username='janelle.layton', email='janelle.layton@my.hamptonu.edu', last_activity=datetime.datetime(2025, 3, 12, 21, 55, 56, 4956, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ja', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=96, first_name='', last_name='', username='william.wu.043', email='william.wu.043@gmail.com', last_activity=datetime.datetime(2025, 8, 17, 18, 45, 31, 609383, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='wi', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=126, first_name='', last_name='', username='sraswan', email='sraswan@ucsd.edu', last_activity=datetime.datetime(2025, 5, 2, 19, 51, 46, 648304, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sr', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=92, first_name='', last_name='', username='cam022', email='cam022@ucsd.edu', last_activity=datetime.datetime(2025, 4, 17, 3, 44, 25, 267832, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ca', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=87, first_name='', last_name='', username='lhardy', email='lhardy@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 2, 31, 59, 529189, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='lh', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=27, first_name='', last_name='', username='bsemmens', email='bsemmens@ucsd.edu', last_activity=datetime.datetime(2025, 7, 14, 16, 37, 30, 71461, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='bs', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=117, first_name='', last_name='', username='tim_edwards', email='tim_edwards@usa.net', last_activity=datetime.datetime(2025, 7, 12, 19, 47, 8, 519498, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ti', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=93, first_name='', last_name='', username='hetobias', email='hetobias@ucsd.edu', last_activity=datetime.datetime(2025, 5, 28, 23, 14, 14, 952377, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='he', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=140, first_name='', last_name='', username='theo.darcimaher', email='theo.darcimaher@gmail.com', last_activity=datetime.datetime(2025, 7, 31, 21, 57, 7, 835046, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='th', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=98, first_name='', last_name='', username='scott.heppell', email='scott.heppell@oregonstate.edu', last_activity=datetime.datetime(2025, 5, 28, 23, 10, 13, 221094, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sc', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=103, first_name='', last_name='', username='seanthesheep22+labeler', email='seanthesheep22+labeler@outlook.com', last_activity=datetime.datetime(2025, 3, 13, 3, 3, 31, 590418, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='se', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=132, first_name='', last_name='', username='tpalacky', email='tpalacky@gmail.com', last_activity=datetime.datetime(2025, 5, 22, 23, 1, 14, 649129, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='tp', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=109, first_name='', last_name='', username='eci1', email='eci1@reef.org', last_activity=datetime.datetime(2025, 8, 2, 14, 46, 30, 664702, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ec', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=108, first_name='', last_name='', username='mmc003', email='mmc003@ucsd.edu', last_activity=datetime.datetime(2025, 4, 1, 22, 3, 50, 192408, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='mm', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=113, first_name='', last_name='', username='b.jeff.williams', email='b.jeff.williams@gmail.com', last_activity=datetime.datetime(2025, 4, 2, 23, 54, 34, 49915, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='b.', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=101, first_name='', last_name='', username='havasanth', email='havasanth@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 2, 18, 53, 253836, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ha', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=86, first_name='', last_name='', username='joh048', email='joh048@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 3, 9, 23, 83225, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='jo', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=89, first_name='', last_name='', username='jasonjuranwang', email='jasonjuranwang@gmail.com', last_activity=datetime.datetime(2025, 3, 13, 22, 12, 40, 94549, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ja', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=105, first_name='', last_name='', username='rlmao', email='rlmao@ucsd.edu', last_activity=datetime.datetime(2025, 3, 26, 5, 3, 41, 179957, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='rl', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=102, first_name='', last_name='', username='npetrone', email='npetrone@ucsd.edu', last_activity=datetime.datetime(2025, 3, 13, 3, 9, 59, 366626, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='np', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=110, first_name='', last_name='', username='martabonatz', email='martabonatz@yahoo.com', last_activity=datetime.datetime(2025, 4, 3, 20, 46, 14, 543661, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ma', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=112, first_name='', last_name='', username='tbakerlaguna', email='tbakerlaguna@yahoo.com', last_activity=datetime.datetime(2025, 4, 2, 23, 54, 41, 223241, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='tb', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=114, first_name='', last_name='', username='carolyn.corley', email='carolyn.corley@reef.org', last_activity=datetime.datetime(2025, 4, 3, 15, 14, 59, 553750, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ca', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=116, first_name='Tom', last_name='Zhang', username='shz078', email='shz078@ucsd.edu', last_activity=datetime.datetime(2025, 4, 3, 17, 7, 58, 20180, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='TZ', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=115, first_name='', last_name='', username='diana.phillips', email='diana.phillips@owuscholarship.org', last_activity=datetime.datetime(2025, 4, 8, 20, 12, 37, 863614, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='di', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=118, first_name='', last_name='', username='cinagaki', email='cinagaki@ucsd.edu', last_activity=datetime.datetime(2025, 4, 16, 21, 29, 8, 95042, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ci', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=107, first_name='', last_name='', username='jadascuba', email='jadascuba@gmail.com', last_activity=datetime.datetime(2025, 5, 2, 15, 45, 26, 432539, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ja', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=29, first_name='Dottie', last_name='Benjamin', username='scubadot', email='scubadot@gmail.com', last_activity=datetime.datetime(2025, 8, 25, 22, 24, 59, 105299, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='DB', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=143, first_name='', last_name='', username='rekasius10', email='rekasius10@gmail.com', last_activity=datetime.datetime(2025, 8, 21, 23, 28, 23, 544025, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='re', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=131, first_name='Kshitij', last_name='Khandagale', username='kshitijkhandagale2007', email='kshitijkhandagale2007@gmail.com', last_activity=datetime.datetime(2025, 8, 27, 3, 27, 29, 103775, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='KK', phone='6163490629', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=62, first_name='alyssa', last_name='attie', username='alyssaattie1999', email='alyssaattie1999@gmail.com', last_activity=datetime.datetime(2025, 8, 23, 23, 52, 13, 559411, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='aa', phone='9547079492', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=163, first_name='', last_name='', username='ashleyundersea', email='ashleyundersea@gmail.com', last_activity=datetime.datetime(2025, 7, 27, 20, 26, 3, 446761, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='as', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=141, first_name='', last_name='', username='brendonmwamba7', email='brendonmwamba7@gmail.com', last_activity=datetime.datetime(2025, 7, 15, 20, 48, 47, 645680, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='br', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=138, first_name='', last_name='', username='anchen27', email='anchen27@amherst.edu', last_activity=datetime.datetime(2025, 7, 16, 16, 32, 21, 896372, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='an', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=160, first_name='', last_name='', username='imogenparker17', email='imogenparker17@gmail.com', last_activity=datetime.datetime(2025, 7, 13, 16, 53, 32, 702548, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='im', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=162, first_name='', last_name='', username='daisyelizabethanderson1', email='daisyelizabethanderson1@gmail.com', last_activity=datetime.datetime(2025, 8, 9, 20, 58, 22, 610976, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='da', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=4, first_name='Christopher', last_name='Crutchfield', username='ccrutchf', email='ccrutchf@ucsd.edu', last_activity=datetime.datetime(2025, 9, 1, 1, 32, 2, 562671, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='CC', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=164, first_name='', last_name='', username='asjajodia', email='asjajodia@gmail.com', last_activity=datetime.datetime(2025, 8, 1, 3, 4, 37, 586908, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='as', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=139, first_name='', last_name='', username='aayushkab.2003', email='aayushkab.2003@gmail.com', last_activity=datetime.datetime(2025, 7, 21, 22, 23, 16, 477171, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='aa', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=136, first_name='', last_name='', username='celinenavar', email='celinenavar@gmail.com', last_activity=datetime.datetime(2025, 6, 4, 22, 47, 40, 474426, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='ce', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None),
#  LseUserApi(id=33, first_name='Andy', last_name='Prochaska', username='ajpro', email='ajpro@outlook.com', last_activity=datetime.datetime(2025, 9, 1, 20, 33, 51, 405896, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='AP', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=142, first_name='', last_name='', username='sijan.shrestha0112', email='sijan.shrestha0112@gmail.com', last_activity=datetime.datetime(2025, 8, 5, 21, 3, 55, 294827, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='si', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=159, first_name='', last_name='', username='asheyundersea', email='asheyundersea@gmail.com', last_activity=datetime.datetime(2025, 7, 12, 17, 17, 56, 348285, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='as', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=True, date_joined=None, org_membership=None),
#  LseUserApi(id=219, first_name='', last_name='', username='srisowndariyatn', email='srisowndariyatn@gmail.com', last_activity=datetime.datetime(2025, 8, 21, 6, 25, 43, 919850, tzinfo=datetime.timezone.utc), custom_hotkeys=None, avatar=None, initials='sr', phone='', active_organization=1, active_organization_meta=None, allow_newsletters=False, date_joined=None, org_membership=None)]
